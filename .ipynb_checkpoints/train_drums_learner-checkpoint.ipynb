# %%
# %load_ext autoreload
# %autoreload 2
from dataset import iterable_dataset, vae_feature_dataset
from models.music_generation_gru import MusicGRU
import os
from utils import training_rnn, data_reading
import torch
from torch.utils.data import DataLoader
import pickle
import matplotlib.pyplot as plt
from utils import data_reading, music_generation
from models import feature_prediction_gru
from dataset import iterable_dataset

# %%
FEATURE_DIRPATH = "./saved_model_and_data/transformed_features/drums"
TRAIN_SPLIT = 0.95
SEQ_LEN = 48
RESOLUTION = 12
TRACK_ORDER = ["Drums", "Piano"]
FILES_TO_READ = 99999
BATCH_SIZE = 64
LATENT_SIZE = 513
HIDDEN_SIZE = 512
N_LAYER = 3
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
LR_LAMBDA = 1
LR = 0.0001
ALPHA = 0
AUTO_SAVE = False
SAVE_ON_EPOCH = 1

# %%
all_feature_files = data_reading.read_all_npys(FEATURE_DIRPATH, True)

# %%
train_len = round(len(all_feature_files)*TRAIN_SPLIT)
train_files_list = all_feature_files[:train_len]
test_files_list = all_feature_files[train_len:]

# %%
train_dataset = vae_feature_dataset.IterableSongDataset(train_files_list, SEQ_LEN, TRACK_ORDER, FILES_TO_READ, RESOLUTION)
test_dataset = vae_feature_dataset.IterableSongDataset(test_files_list, SEQ_LEN, TRACK_ORDER, FILES_TO_READ, RESOLUTION)
train_loader = DataLoader(train_dataset, batch_size = BATCH_SIZE, drop_last=True)
test_loader = DataLoader(test_dataset, batch_size = BATCH_SIZE, drop_last=True)

# %%
model = feature_prediction_gru.FeaturePredictionGRU(["Drums"], LATENT_SIZE, HIDDEN_SIZE, BATCH_SIZE, N_LAYER, DEVICE).to(DEVICE)

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=LR)
scheduler = torch.optim.lr_scheduler.LambdaLR(optimizer, lr_lambda = lambda epoch: LR_LAMBDA ** epoch)
criterion = torch.nn.MSELoss()

# %%
EPOCH = 80
train_losses, test_losses = training_rnn.training_rnn(model, optimizer, scheduler, criterion, train_loader, test_loader, EPOCH, DEVICE, BATCH_SIZE, 
                         ALPHA, AUTO_SAVE, SAVE_ON_EPOCH)
# Out:
# [0.0001]
# start test
# Epoch 1, Train Loss: 0.17469413978132334, Test Loss: 0.1715878830714659, Time: 2022-04-26 14:33:30.572588
# [0.0001]
# start test
# Epoch 2, Train Loss: 0.16826944048093123, Test Loss: 0.16664782776073975, Time: 2022-04-26 14:34:20.649587
# [0.0001]
# start test
# Epoch 3, Train Loss: 0.16576919982379132, Test Loss: 0.1647465472871607, Time: 2022-04-26 14:35:10.083088
# [0.0001]
# start test
# Epoch 4, Train Loss: 0.16407049022276293, Test Loss: 0.16322392868724736, Time: 2022-04-26 14:36:23.545087
# [0.0001]
# start test
# Epoch 5, Train Loss: 0.16227792520076037, Test Loss: 0.16111318055878987, Time: 2022-04-26 14:37:25.679588
# [0.0001]
# start test
# Epoch 6, Train Loss: 0.16020690988410602, Test Loss: 0.15950817716392604, Time: 2022-04-26 14:38:02.313587
# [0.0001]
# start test
# Epoch 7, Train Loss: 0.15795436071401292, Test Loss: 0.15781436589631168, Time: 2022-04-26 14:38:14.674089
# [0.0001]
# start test
# Epoch 8, Train Loss: 0.1555920699949969, Test Loss: 0.1561631875281984, Time: 2022-04-26 14:38:27.086087
# [0.0001]
# start test
# Epoch 9, Train Loss: 0.1527430169792338, Test Loss: 0.1550299460915002, Time: 2022-04-26 14:38:39.543587
# [0.0001]
# start test
# Epoch 10, Train Loss: 0.14977803323417901, Test Loss: 0.15400003337047316, Time: 2022-04-26 14:38:52.059588
# [0.0001]
# start test
# Epoch 11, Train Loss: 0.14674559958617794, Test Loss: 0.1530460681427609, Time: 2022-04-26 14:39:04.502087
# Epoch 35, Train Loss: 0.09112837848846209, Test Loss: 0.12897106598724017, Time: 2022-04-26 14:45:08.721589
# [0.0001]
# start test
# Epoch 36, Train Loss: 0.08987554255026307, Test Loss: 0.12835492633960463, Time: 2022-04-26 14:45:21.641087
# [0.0001]
# start test
# Epoch 37, Train Loss: 0.08867336185649037, Test Loss: 0.12760928950526498, Time: 2022-04-26 14:45:34.611588
# [0.0001]
# start test
# Epoch 38, Train Loss: 0.0874736429954117, Test Loss: 0.12724060700698334, Time: 2022-04-26 14:45:47.517087
# [0.0001]
# start test
# Epoch 39, Train Loss: 0.08643633465875279, Test Loss: 0.12716236100955444, Time: 2022-04-26 14:46:00.391588
# [0.0001]
# start test
# Epoch 40, Train Loss: 0.085151335072111, Test Loss: 0.12673762914809314, Time: 2022-04-26 14:46:13.263087
# [0.0001]
# start test
# Epoch 41, Train Loss: 0.08402242060242729, Test Loss: 0.1267835653641007, Time: 2022-04-26 14:46:26.195088
# [0.0001]
# start test
# Epoch 42, Train Loss: 0.082835627973757, Test Loss: 0.1271692473780025, Time: 2022-04-26 14:46:39.661090
# [0.0001]
# start test
# Epoch 43, Train Loss: 0.08215278285470876, Test Loss: 0.12699116224592383, Time: 2022-04-26 14:47:00.236588
# [0.0001]
# start test
# Epoch 44, Train Loss: 0.08107180955227125, Test Loss: 0.12628474526784636, Time: 2022-04-26 14:47:29.133589
# [0.0001]
# start test
# Epoch 45, Train Loss: 0.08010239028795199, Test Loss: 0.1259127100082961, Time: 2022-04-26 14:47:42.159087
# [0.0001]
# start test
# Epoch 46, Train Loss: 0.0790699446150525, Test Loss: 0.12662932683121075, Time: 2022-04-26 14:47:55.182589
# [0.0001]
# start test
# Epoch 47, Train Loss: 0.07824878425930035, Test Loss: 0.12586801939389922, Time: 2022-04-26 14:48:08.055590
# [0.0001]
# start test
# Epoch 48, Train Loss: 0.07723571182313291, Test Loss: 0.12607590921900488, Time: 2022-04-26 14:48:20.957089
# [0.0001]
# start test
# Epoch 49, Train Loss: 0.07630006072365425, Test Loss: 0.1266573935069821, Time: 2022-04-26 14:48:33.963587
# [0.0001]
# start test
# Epoch 50, Train Loss: 0.07548363256183538, Test Loss: 0.1261778954755176, Time: 2022-04-26 14:48:46.898088
# [0.0001]
# start test
# Epoch 51, Train Loss: 0.07471485132012855, Test Loss: 0.1253170066259124, Time: 2022-04-26 14:48:59.867088
# [0.0001]
# start test
# Epoch 52, Train Loss: 0.07392172330821102, Test Loss: 0.12627430361780254, Time: 2022-04-26 14:49:12.789088
# [0.0001]
# start test
# Epoch 53, Train Loss: 0.07314180802892555, Test Loss: 0.1259012950414961, Time: 2022-04-26 14:49:25.651587
# [0.0001]
# start test
# Epoch 54, Train Loss: 0.07243037505752661, Test Loss: 0.12566780739209868, Time: 2022-04-26 14:49:38.779589
# [0.0001]
# start test
# Epoch 55, Train Loss: 0.0718214314176955, Test Loss: 0.12470070171085271, Time: 2022-04-26 14:49:51.757587
# [0.0001]
# start test
# Epoch 56, Train Loss: 0.07115573839030483, Test Loss: 0.12479636276310141, Time: 2022-04-26 14:50:04.650587
# [0.0001]
# start test
# Epoch 57, Train Loss: 0.07046956574036316, Test Loss: 0.12370414930311116, Time: 2022-04-26 14:50:17.600589
# [0.0001]
# start test
# Epoch 58, Train Loss: 0.06980818408456715, Test Loss: 0.12367482720450922, Time: 2022-04-26 14:50:30.552088
# [0.0001]
# start test
# Epoch 59, Train Loss: 0.06909951242533598, Test Loss: 0.12297676063396713, Time: 2022-04-26 14:50:43.557587
# [0.0001]
# start test
# Epoch 60, Train Loss: 0.06853660974143581, Test Loss: 0.12359191070903432, Time: 2022-04-26 14:50:56.532088
# [0.0001]
# start test
# Epoch 61, Train Loss: 0.06793836851350286, Test Loss: 0.1223614930429242, Time: 2022-04-26 14:51:09.438588
# [0.0001]
# start test
# Epoch 62, Train Loss: 0.06747403751042756, Test Loss: 0.12330131131139668, Time: 2022-04-26 14:51:22.431088
# [0.0001]
# start test
# Epoch 63, Train Loss: 0.06690397763794119, Test Loss: 0.12280637635426088, Time: 2022-04-26 14:51:35.642591
# [0.0001]
# start test
# Epoch 64, Train Loss: 0.06656985550441526, Test Loss: 0.12360390241850507, Time: 2022-04-26 14:51:48.849088
# [0.0001]
# start test
# Epoch 65, Train Loss: 0.06594317277724093, Test Loss: 0.12312284890900958, Time: 2022-04-26 14:52:01.946087
# [0.0001]
# start test
# Epoch 66, Train Loss: 0.06509772123430263, Test Loss: 0.12434285201809624, Time: 2022-04-26 14:52:15.046087
# [0.0001]
# start test
# Epoch 67, Train Loss: 0.06440647682175041, Test Loss: 0.12331153283065016, Time: 2022-04-26 14:52:28.119589
# [0.0001]
# start test
# Epoch 68, Train Loss: 0.06396001143888994, Test Loss: 0.12377574531869455, Time: 2022-04-26 14:52:41.224088
# [0.0001]
# start test
# Epoch 69, Train Loss: 0.06341087910431352, Test Loss: 0.1222141097215089, Time: 2022-04-26 14:52:54.286587
# [0.0001]
# start test
# Epoch 70, Train Loss: 0.06313409635966474, Test Loss: 0.12216958437453616, Time: 2022-04-26 14:53:07.341587
# [0.0001]
# start test
# Epoch 71, Train Loss: 0.06250175744803114, Test Loss: 0.12188570269129494, Time: 2022-04-26 14:53:20.367088
# [0.0001]
# start test
# Epoch 72, Train Loss: 0.06209897371008992, Test Loss: 0.12187988480383699, Time: 2022-04-26 14:53:33.474587
# [0.0001]
# start test
# Epoch 73, Train Loss: 0.061757399006323384, Test Loss: 0.12125021456317468, Time: 2022-04-26 14:53:46.580587
# [0.0001]
# start test
# Epoch 74, Train Loss: 0.06132126400585879, Test Loss: 0.12096360258080742, Time: 2022-04-26 14:53:59.618587
# [0.0001]
# start test
# Epoch 75, Train Loss: 0.06087415914305232, Test Loss: 0.12139080261642282, Time: 2022-04-26 14:54:12.771087
# [0.0001]
# start test
# Epoch 76, Train Loss: 0.060364800793203444, Test Loss: 0.12142190540378744, Time: 2022-04-26 14:54:25.858588
# [0.0001]
# start test
# Epoch 77, Train Loss: 0.0597977642308582, Test Loss: 0.12170459499413316, Time: 2022-04-26 14:54:39.032587
# [0.0001]
# start test
# Epoch 78, Train Loss: 0.059471813674000173, Test Loss: 0.12122418189590628, Time: 2022-04-26 14:54:51.949587
# [0.0001]
# start test
# Epoch 79, Train Loss: 0.05929261225021698, Test Loss: 0.12159651314670389, Time: 2022-04-26 14:55:04.824088
# [0.0001]
# start test
# Epoch 80, Train Loss: 0.05897523586384275, Test Loss: 0.12127890437841415, Time: 2022-04-26 14:55:17.964590

# %%
plt.rcParams["figure.figsize"] = (15,15)
plt.plot(train_losses, label = 'Train Loss')
plt.plot(test_losses, label = 'Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

# %%
STRINGS_SAVE_PATH = f"./saved_model_and_data/learner/drums_based_on_piano/drums_learner_epoch{EPOCH}"
torch.save(model.state_dict(), STRINGS_SAVE_PATH)
